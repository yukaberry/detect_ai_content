# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import pickle

from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder

from sklearn import set_config; set_config(display='diagram')

# %%
def get_huggingface_texts(number):
    path = "../../raw_data/huggingface.co_human_ai_generated_text/model_training_dataset.csv"

    # Extract a small dataset
    chunksize = number
    huggingface_df = None

    for chunk in pd.read_csv(path, chunksize=chunksize):
        # chunk is a DataFrame. To "process" the rows in the chunk:
        huggingface_df = chunk
        break

    huggingface_human_text_df = huggingface_df[["id", "human_text"]]
    huggingface_human_text_df = huggingface_human_text_df.rename(columns={'human_text':'text'},)
    huggingface_human_text_df['generated'] = 0

    huggingface_ai_text_df = huggingface_df[["id", "ai_text"]]
    huggingface_ai_text_df = huggingface_ai_text_df.rename(columns={'ai_text':'text'},)
    huggingface_ai_text_df['generated'] = 1

    huggingface_sample_text_df = pd.concat(objs=[huggingface_human_text_df, huggingface_ai_text_df])
    return huggingface_sample_text_df

# %%
df = get_huggingface_texts(1000)

# %%
# https://github.com/PrithivirajDamodaran/Gramformer
# pip install -U git+https://github.com/PrithivirajDamodaran/Gramformer.git
# python -m spacy download en_core_web_sm

from gramformer import Gramformer
import torch

def set_seed(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(1212)

gf = Gramformer(models = 1, use_gpu=False) # 1=corrector, 2=detector

for index, row in df.iterrows():
    text = row['text']
    generated = row['generated']

    for sentence in text.split("."):
        sentence = sentence.strip()
        sentence = f"{sentence}."
        corrected_sentences = gf.correct(f"{sentence}.", max_candidates=1)
        corrected_sentence = list(corrected_sentences)[0]
        if sentence == corrected_sentence:
            print(f"✅ {generated}\t")
        else:
            print(f"❌ {generated}\t")
            print(f"{sentence}")
            print(f"{corrected_sentence}")
# Out:
# /Users/jeromemorissard/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /Users/jeromemorissard/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# [Gramformer] Grammar error correct/highlight model loaded..
# ✅ 0
# ❌ 0
# Some school have decreased bullying and high and middle school because some students get bullied.
# Some schools have decreased bullying in high and middle school because some students get bullied.
# ❌ 0
# Some Schools offter distance learning as an option for students to attend classes from home by way of online or video conferencing.
# Some schools offer distance learning as an option for students to attend classes from home by way of online or video conferencing.
# ❌ 0
# Students can ncreased to learn at home.
# Students can continue to learn at home.
# ❌ 0
# Also is more hard to students understand by online.
# Also is more difficult for students to understand online.
# ❌ 0
# students get distract at home.
# students get distracted at home.
# ❌ 0
# Some schools in United States ofter classes from home because is good option to students.
# Some schools in United States offer classes from home because it is a good option for students.
# ❌ 0
# Also students can stay more relaxing from home.
# Also students can stay more relaxed from home.
# ❌ 0
# Students don't want to go more at school and they want to get classes at home.
# Students don't want to go to school and they want to get classes at home.
# ✅ 0
# ✅ 0
# ❌ 0
# Students can get distract at home because they have easy to use phones.
# Students can get distracted at home because they have easy to use phones.
# ✅ 0
# ❌ 0
# They feel more bored at home because they need stay at home more time.
# They feel more bored at home because they need to stay at home more time.
# ❌ 0
# Also students don't do anything at home because if they stay at home is esay to get more distract.
# Also students don't do anything at home because if they stay at home is said to get more distracted.
# ❌ 0
# Students can get fall in environment learning and is hard they learn at home.
# Students can fall into environment learning and is hard to learn at home.
# ✅ 0
# ❌ 0
# Also they don't want to learn by online.
# Also, they don't want to learn online.
# ❌ 0
# Also many students have hard time in class to understand that teacher explain in more hard they learn at home.
# Many students have a hard time in class to understand that the teacher explains how hard they learn at home.
# ❌ 0
# Some schools affter classes from home because they think is good option to students.
# Some schools alternate classes from home because they think it is a good option for students.
# ❌ 0
# If they get classes at home they don't learning.
# If they get classes at home they don't learn.
# ❌ 0
# Many students work and they would tired and they don't want to learn.
# Many students work and they are tired and they don't want to learn.
# ❌ 0
# Students don't pay attention in class they too don't pay attention at home because is more hard.
# Students don't pay attention in class, they too don't pay attention at home because it is harder.
# ❌ 0
# But students get more distract stay near the family and they don't want to pay attention.
# But students get more distracted when they stay near the family and they don't want to pay attention.
# ❌ 0
# Conclude if students get classes from home by online they don't want to pay attention because is more easy they get distract.
# Conclude if students get classes from home or online they don't want to pay attention because it is more easy they get distracted.
# ✅ 0
# ❌ 0
# Also they want to play or use phone and not is good option to students get class at home they get distration and decrease to learning.
# Also they want to play or use phone and not is good option for students to get class at home they get distration and decrease in learning.
# ❌ 0
# Also students get frustration in class because they don't understand but if they get classes in online they don't learning too because is more hard they learning from home.
# Also students get frustrated in class because they don't understand but if they get classes online they don't learn too because it is harder to learn from home.
# ❌ 0
# .
# ..
# ❌ 0
# Also they want to listening to music or play.
# Also they want to listen to music or play.
# ❌ 0
# Students fall in environment learning because they learn at class when the teacher explain if students attend classes from home by online is hard they learn.
# Students fall in the environment learning because they learn in class when the teacher explains if students attend classes from home by online is hard they learn.
# ❌ 0
# Also student sleep more and stay with more energy to receive the class by online.
# Students sleep more and stay with more energy to receive the class online.
# ❌ 0
# Also they feel safe at home with their family.
# They also feel safe at home with their family.
# ✅ 0
# ❌ 0
# In my family, my dad is the one who is always at work, he works from 8am to 6pm everyday, he doesn't have a day off, but it is okay for him.
# In my family, my dad is the one who is always at work, he works from 8am to 6pm everyday, he doesn't have a day off, but it is okay for him..
# ✅ 0
# ✅ 0
# ❌ 0
# A four-day school week benefit students and teachers in many ways, students would have a day off and time to do extra curricular activities such as sports or work, teachers would be at home and have time to spend with their kids and be with the family, and all of us would be conserving energy and resources.
# A four-day school week benefits students and teachers in many ways, students would have a day off and time to do extra curricular activities such as sports or work, teachers would be at home and have time to spend with their kids and be with the family, and all of us would be conserving energy
# ❌ 0
# Therefore i think my school should follow this model and extend the school day two hours in a four-day school week.
# Therefore I think my school should follow this model and extend the school day two hours in a four-day school week.
# ❌ 0
# Students would be happy of having a day off, and most of them would support the idea of having a four-day school week.
# Students would be happy having a day off, and most of them would support the idea of having a four-day school week.
# ✅ 0
# ❌ 0
# In conclusion, i think having a four-day school week, would benefit a lot of people, because just like me, there are plenty of students that would love to work more and generate money, and for the teachers, well they would enjoy have a day off and spend time with their kids at home.
# In conclusion, i think having a four-day school week, would benefit a lot of people, because just like me, there are plenty of students that would love to work more and generate more money, and for the teachers, well they would enjoy having a day off and spending time with their
# ❌ 0
# .
# ..
# ✅ 0
# ❌ 0
# One disadvantage of having a four-day school week is that some parents work 5 days a week in different companies and these companies might not have the four-day work week so they won't have time to be with their kids at home in the day off, and some of them would be forced to change their five-day work week to a four-day work week, so they can be with their kids at home.
# One disadvantage of having a four-day school week is that some parents work 5 days a week in different companies and these companies might not have the four-day work week so they won't have time to be with their kids at home on the day off, and some of them would be forced to
# ❌ 0
# Personally, i would prefer the four-day school week, because,i have a part-time job after school , it is from 5 to 10pm, and having a day off would allow me to have time to do some extra work at home and to change my schedule for in the morning so i can have the rest of the day to work on my stuffs, have time to chill, or maybe to do my homework, and help my mom with whatever she needs.
# Personally, I would prefer the four-day school week, because I have a part-time job after school, it is from 5 to 10pm, and having a day off would allow me to have time to do some extra work at home and to change my schedule for in the morning so i
# ❌ 0
# Having a four-day school week, would let me have time to do a lot of things during the day, for example, babysit my little brother if my mom goes out, go to the gym or maybe help my dad.
# Having a four-day school week, would let me have time to do a lot of things during the day, for example, babysit my little brother if my mom goes out, go to the gym or maybe help my dad..
# ❌ 0
# parents and school should agree on the desicions of wha is going to be better for the students.
# Parents and school should agree on the decisions of what is going to be better for the students.
# ❌ 0
# Parents as being the ones giving permission to the students, should considered any type of activitie that the student wants to get involved in.
# Parents as being the ones giving permission to the students, should consider any type of activity that the student wants to get involved in.
# ✅ 0
# ❌ 0
# Activities at school should not be controling, or making the students join so many activities.
# Activities at school should not be controlled, or making the students join so many activities.
# ❌ 0
# If the student does not do the school work, then they will have bad grades, that will affect them by not being able to participate anymore in any of the school actiities.
# If the student does not do the school work, then they will have bad grades, that will affect them by not being able to participate anymore in any of the school activities.
# ❌ 0
# The school should make an runion for parents, so they can agree on the terms that the school want.
# The school should make a reunion for parents, so they can agree on the terms that the school wants.
# ❌ 0
# .
# ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 24
#      22 sentence = sentence.strip()
#      23 sentence = f"{sentence}."
# ---> 24 corrected_sentences = gf.correct(f"{sentence}.", max_candidates=1)
#      25 corrected_sentence = list(corrected_sentences)[0]
#      26 if sentence == corrected_sentence:
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/gramformer/gramformer.py:37, in Gramformer.correct(self, input_sentence, max_candidates)
#      34         input_ids = self.correction_tokenizer.encode(input_sentence, return_tensors='pt')
#      35         input_ids = input_ids.to(self.device)
# ---> 37         preds = self.correction_model.generate(
#      38             input_ids,
#      39             do_sample=True,
#      40             max_length=128,
#      41 #             top_k=50,
#      42 #             top_p=0.95,
#      43             num_beams=7,
#      44             early_stopping=True,
#      45             num_return_sequences=max_candidates)
#      47         corrected = set()
#      48         for pred in preds:
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/generation/utils.py:2246, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2238     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2239         input_ids=input_ids,
#    2240         expand_size=generation_config.num_beams,
#    2241         is_encoder_decoder=self.config.is_encoder_decoder,
#    2242         **model_kwargs,
#    2243     )
#    2245     # 13. run beam sample
# -> 2246     result = self._beam_search(
#    2247         input_ids,
#    2248         beam_scorer,
#    2249         logits_processor=prepared_logits_processor,
#    2250         stopping_criteria=prepared_stopping_criteria,
#    2251         generation_config=generation_config,
#    2252         synced_gpus=synced_gpus,
#    2253         **model_kwargs,
#    2254     )
#    2256 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2257     # 11. prepare beam search scorer
#    2258     beam_scorer = BeamSearchScorer(
#    2259         batch_size=batch_size,
#    2260         num_beams=generation_config.num_beams,
#    (...)
#    2266         max_length=generation_config.max_length,
#    2267     )
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/generation/utils.py:3455, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3452     outputs = stack_model_outputs(outputs_per_sub_batch, self.config.get_text_config())
#    3454 else:  # Unchanged original behavior
# -> 3455     outputs = self(**model_inputs, return_dict=True)
#    3457 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3458 model_kwargs = self._update_model_kwargs_for_generation(
#    3459     outputs,
#    3460     model_kwargs,
#    3461     is_encoder_decoder=self.config.is_encoder_decoder,
#    3462 )
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1891, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1888         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1890 # Decode
# -> 1891 decoder_outputs = self.decoder(
#    1892     input_ids=decoder_input_ids,
#    1893     attention_mask=decoder_attention_mask,
#    1894     inputs_embeds=decoder_inputs_embeds,
#    1895     past_key_values=past_key_values,
#    1896     encoder_hidden_states=hidden_states,
#    1897     encoder_attention_mask=attention_mask,
#    1898     head_mask=decoder_head_mask,
#    1899     cross_attn_head_mask=cross_attn_head_mask,
#    1900     use_cache=use_cache,
#    1901     output_attentions=output_attentions,
#    1902     output_hidden_states=output_hidden_states,
#    1903     return_dict=return_dict,
#    1904     cache_position=cache_position,
#    1905 )
#    1907 sequence_output = decoder_outputs[0]
#    1909 # Set device for model parallelism
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1124, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1107     layer_outputs = self._gradient_checkpointing_func(
#    1108         layer_module.forward,
#    1109         hidden_states,
#    (...)
#    1121         cache_position,
#    1122     )
#    1123 else:
# -> 1124     layer_outputs = layer_module(
#    1125         hidden_states,
#    1126         attention_mask=causal_mask,
#    1127         position_bias=position_bias,
#    1128         encoder_hidden_states=encoder_hidden_states,
#    1129         encoder_attention_mask=encoder_extended_attention_mask,
#    1130         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1131         layer_head_mask=layer_head_mask,
#    1132         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1133         past_key_value=past_key_values,
#    1134         use_cache=use_cache,
#    1135         output_attentions=output_attentions,
#    1136         return_dict=return_dict,
#    1137         cache_position=cache_position,
#    1138     )
#    1140 # layer_outputs is a tuple with:
#    1141 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1142 if use_cache is False:
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:725, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict, cache_position)
#     722     attention_outputs = attention_outputs + cross_attention_outputs[2:]
#     724 # Apply Feed Forward layer
# --> 725 hidden_states = self.layer[-1](hidden_states)
#     727 # clamp inf values to enable fp16 training
#     728 if hidden_states.dtype == torch.float16:
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:339, in T5LayerFF.forward(self, hidden_states)
#     337 def forward(self, hidden_states):
#     338     forwarded_states = self.layer_norm(hidden_states)
# --> 339     forwarded_states = self.DenseReluDense(forwarded_states)
#     340     hidden_states = hidden_states + self.dropout(forwarded_states)
#     341     return hidden_states
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:284, in T5DenseActDense.forward(self, hidden_states)
#     283 def forward(self, hidden_states):
# --> 284     hidden_states = self.wi(hidden_states)
#     285     hidden_states = self.act(hidden_states)
#     286     hidden_states = self.dropout(hidden_states)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import spacy
import contextualSpellCheck

nlp = spacy.load('en_core_web_sm')
contextualSpellCheck.add_to_pipe(nlp)
doc = nlp('This is my neww job. My firsrt neme is Jack.')

print(len(doc._.suggestions_spellCheck)) # => Number of errors: 3
print(doc._.suggestions_spellCheck)      # => {neww: 'new', firsrt: 'best', neme: 'name'}
print(doc._.outcome_spellCheck)          # => This is my new job. My best name is Jack.
# Out:
# 3
# {neww: 'new', firsrt: 'best', neme: 'name'}
# This is my new job. My best name is Jack.

# %%
for index, row in df.iterrows():
    text = row['text']
    generated = row['generated']

    errors_nb = 0
    for sentence in text.split(". "):
        doc = nlp(f"{sentence}.")
        errors_nb += len(doc._.suggestions_spellCheck)

    print(f"{errors_nb}\t")
# Out:
# 8
# 8
# 22
# 1
# 0
# 6
# 10
# 12
# 10
# 17
# 8
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 7
#       5 errors_nb = 0
#       6 for sentence in text.split(". "):
# ----> 7     doc = nlp(f"{sentence}.")
#       8     errors_nb += len(doc._.suggestions_spellCheck)
#      10 print(f"{errors_nb}\t")
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/spacy/language.py:1052, in Language.__call__(self, text, disable, component_cfg)
#    1050     error_handler = proc.get_error_handler()
#    1051 try:
# -> 1052     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1053 except KeyError as e:
#    1054     # This typically happens if a component is not initialized
#    1055     raise ValueError(Errors.E109.format(name=name)) from e
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/contextualSpellCheck/contextualSpellCheck.py:170, in ContextualSpellCheck.__call__(self, doc)
#     168         doc._.set("outcome_spellCheck", cleaned_sentence)
#     169 else:
# --> 170     misspell_tokens, doc = self.misspell_identify(doc)
#     171     if len(misspell_tokens) > 0:
#     172         doc, candidate = self.candidate_generator(doc, misspell_tokens)
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/contextualSpellCheck/contextualSpellCheck.py:246, in ContextualSpellCheck.misspell_identify(self, doc, query)
#     220 """To identify misspelled words from the query
#     221
#     222 At present, All the following criteria should be met for word to be
#    (...)
#     240     `tuple`: returns `List[`Spacy.Token`]` and `Spacy.Doc`
#     241 """
#     243 # deep copy is required to preserve individual token info
#     244 # from objects in pipeline which can modify token info
#     245 # like merge_entities
# --> 246 docCopy = copy.deepcopy(doc)
#     248 misspell = []
#     249 for token in docCopy:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:265, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     263 if deep and args:
#     264     args = (deepcopy(arg, memo) for arg in args)
# --> 265 y = func(*args)
#     266 if deep:
#     267     memo[id(x)] = y
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:264, in <genexpr>(.0)
#     262 deep = memo is not None
#     263 if deep and args:
# --> 264     args = (deepcopy(arg, memo) for arg in args)
#     265 y = func(*args)
#     266 if deep:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:265, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     263 if deep and args:
#     264     args = (deepcopy(arg, memo) for arg in args)
# --> 265 y = func(*args)
#     266 if deep:
#     267     memo[id(x)] = y
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:264, in <genexpr>(.0)
#     262 deep = memo is not None
#     263 if deep and args:
# --> 264     args = (deepcopy(arg, memo) for arg in args)
#     265 y = func(*args)
#     266 if deep:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:161, in deepcopy(x, memo, _nil)
#     159 reductor = getattr(x, "__reduce_ex__", None)
#     160 if reductor is not None:
# --> 161     rv = reductor(4)
#     162 else:
#     163     reductor = getattr(x, "__reduce__", None)
#
# KeyboardInterrupt:
