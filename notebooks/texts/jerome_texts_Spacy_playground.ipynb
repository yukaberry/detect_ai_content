# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import pickle

from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder

from sklearn import set_config; set_config(display='diagram')

# %%
def get_huggingface_texts(number):
    path = "../../raw_data/huggingface.co_human_ai_generated_text/model_training_dataset.csv"

    # Extract a small dataset
    chunksize = number
    huggingface_df = None

    for chunk in pd.read_csv(path, chunksize=chunksize):
        # chunk is a DataFrame. To "process" the rows in the chunk:
        huggingface_df = chunk
        break

    huggingface_human_text_df = huggingface_df[["id", "human_text"]]
    huggingface_human_text_df = huggingface_human_text_df.rename(columns={'human_text':'text'},)
    huggingface_human_text_df['generated'] = 0

    huggingface_ai_text_df = huggingface_df[["id", "ai_text"]]
    huggingface_ai_text_df = huggingface_ai_text_df.rename(columns={'ai_text':'text'},)
    huggingface_ai_text_df['generated'] = 1

    huggingface_sample_text_df = pd.concat(objs=[huggingface_human_text_df, huggingface_ai_text_df])
    return huggingface_sample_text_df

# %%
df = get_huggingface_texts(10000)

# %%
from textblob import TextBlob

sentences = []
generated = []
parent_id = []

for index, row in df.iterrows():
    blob = TextBlob(row['text'])
    for sentence in blob.sentences:
        sentences.append(sentence.lower())
        generated.append(row['generated'])
        parent_id.append(row['id'])

sentences_df = pd.DataFrame(data={"sentences":sentences, "generated":generated, 'parent_id':parent_id  })
sentences_df.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 10
#       8 blob = TextBlob(row['text'])
#       9 for sentence in blob.sentences:
# ---> 10     sentences.append(sentence.lower())
#      11     generated.append(row['generated'])
#      12     parent_id.append(row['id'])
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/textblob/mixins.py:155, in StringlikeMixin.lower(self)
#     153 def lower(self):
#     154     """Like str.lower(), returns new object with all lower-cased characters."""
# --> 155     return self.__class__(self._strkey().lower())
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/textblob/blob.py:688, in Sentence.__init__(self, sentence, start_index, end_index, *args, **kwargs)
#     687 def __init__(self, sentence, start_index=0, end_index=None, *args, **kwargs):
# --> 688     super().__init__(sentence, *args, **kwargs)
#     689     #: The start index within a TextBlob
#     690     self.start = self.start_index = start_index
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/textblob/blob.py:382, in BaseBlob.__init__(self, text, tokenizer, pos_tagger, np_extractor, analyzer, parser, classifier, clean_html)
#     376     raise NotImplementedError(
#     377         "clean_html has been deprecated. "
#     378         "To remove HTML markup, use BeautifulSoup's "
#     379         "get_text() function"
#     380     )
#     381 self.raw = self.string = text
# --> 382 self.stripped = lowerstrip(self.raw, all=True)
#     383 _initialize_models(
#     384     self, tokenizer, pos_tagger, np_extractor, analyzer, parser, classifier
#     385 )
#
# File ~/.pyenv/versions/3.10.6/envs/detect_ai_content/lib/python3.10/site-packages/textblob/utils.py:20, in lowerstrip(s, all)
#      16     else:
#      17         return s.strip().strip(string.punctuation)
# ---> 20 def lowerstrip(s, all=False):
#      21     """Makes text all lowercase and strips punctuation and whitespace.
#      22
#      23     :param s: The string.
#      24     :param all: Remove all punctuation. If False, only removes punctuation from
#      25         the ends of the string.
#      26     """
#      27     return strip_punc(s.lower().strip(), all=all)
#
# KeyboardInterrupt:

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jeromemorissard/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import string

english_stopwords = stopwords.words('english')

def non_stopwords_repetition(sentence):
    word_occurences = {}
    blob = TextBlob(sentence)

    for w in blob.words:
        if w not in english_stopwords and w not in string.punctuation:
            if w not in word_occurences:
                word_occurences[w]=0
            word_occurences[w] += 1

    repetions = 0
    for k in word_occurences:
        if word_occurences[k] > 1:
            repetions = repetions + word_occurences[k]

    return repetions

df['repetitions'] = df['text'].apply(non_stopwords_repetition)

# %%
def str_lenght(text):
    return len(text)

df['text_lenght'] = df['text'].apply(str_lenght)
df['repetitions_ratio'] = df['repetitions']/df['text_lenght']

# %%
df[df['generated'] == 1]['repetitions_ratio'].mean()
# Out:
# 0.03473119330458222

# %%
sns.scatterplot(data=df, x="text_lenght", y="repetitions_ratio", hue="generated")
# Out:
# <Axes: xlabel='text_lenght', ylabel='repetitions_ratio'>

# %%
df.groupby(['generated'])['repetitions_ratio'].median()
# Out:
# generated
# 0    0.061697
# 1    0.034673
# Name: repetitions_ratio, dtype: float64

# %%
df.groupby(['generated'])['repetitions_ratio'].std()
# Out:
# generated
# 0    0.012117
# 1    0.009793
# Name: repetitions_ratio, dtype: float64
